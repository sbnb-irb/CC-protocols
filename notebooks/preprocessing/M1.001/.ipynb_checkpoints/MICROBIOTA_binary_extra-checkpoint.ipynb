# %% [raw]
# A few commonly used non-antibiotic drugs have recently been associated with changes in gut
# microbiome composition, but the extent of this phenomenon is unknown. We screened >1000
# marketed drugs against 40 representative gut bacterial strains, and found that 24% of the drugs
# with human targets, including members of all therapeutic classes, inhibited the growth of at least
# one strain. Particular classes such as the chemically diverse antipsychotics were overrepresented.
# The effects of human-targeted drugs on gut bacteria are reflected on their antibiotic-like side
# effects in humans and are concordant with existing human cohort studies, providing in vivo
# relevance for our screen. Susceptibility to antibiotics and human-targeted drugs correlates across

# %%
import sys
import os
import json
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython import display

from chemicalchecker import ChemicalChecker 
from chemicalchecker.core import DataSignature
from chemicalchecker.util import Config

# standard python verbosity levels: INFO, WARNING, ERROR, DEBUG, etc.
ChemicalChecker.set_verbosity('INFO')
# %matplotlib inline
# Out:
# [INFO    ] Logging level INFO for logger 'chemicalchecker'.

# %%
#data_path = "/aloy/web_checker/current/sign_links"
#local_cc_dir = './local_cc'
# Our local cc instance
#cc_local = ChemicalChecker(local_cc_dir, custom_data_path=data_path)
# Out:
# 2022-02-08 10:51:02,900 chemicalchecker.core.chemcheck.ChemicalChecker [DEBUG   ] ChemicalChecker with root: ./local_cc
# 2022-02-08 10:51:03,146 chemicalchecker.core.chemcheck.ChemicalChecker [INFO    ] CC root directory exists: ignoring 'custom_data_path'.

# %%
# to share the same local CC folder among protocols...change this later
folder_name = 'local_cc_all'
local_cc = '../../' + folder_name
cc_local = ChemicalChecker(local_cc)

# %% [markdown]
# ## New space

# %%
# Load the raw binary data
# Rows: inchikeys
# Columns: bacterial strains

inputFile="../data/microbiota_raw.csv"

df=pd.read_csv(inputFile,index_col=0)

# Mapping smiles -> inchikey for this dataset
with open('../data/smiles2inchikeys.json') as f:
   smiles2inchikeys = json.load(f)

# %%
space = 'M1'
dataset = 'M1.001'

# %% [markdown]
# ## Signature 0: data standardization and (optional) sanitization

# %%
# Instantiation of signature 0 data structures for the new space: full and reference 
sign_type = 'sign0'
sign0 = cc_local.signature(dataset, sign_type)

# %%
# Before each new signature fitting step it is important to clean up the corresponding space directory: this is both crucial and dangerous!
# It is essential to remove all files, related to the space signature, which have been written from previous runs to avoid conflicts. 
# At the same time, this cleaning step will make a fresh start for the signature so any file which would be important to retain must be moved (saved) in advance.

# cleaning both full and reference datasets
sign0.clear_all()

# %%
# Creating the signature model
# We produce a sign0 full and a sign0 reference. Data are sorted (keys and features).
# A signature which has been redundancy-reduced ('reference`) has fewer molecules. The keys are molecules from the `full` signature and values are molecules from the`reference` set.
            
# Parameters: see for further details http://packages.sbnb-pages.irbbarcelona.org/chemical_checker/_autosummary/chemicalchecker.core.sign0.sign0.html
#    X (matrix or file): actual data.
#    keys (array): row names.
#    features (array): column names.
#    do_triplets (boolean): set to False to avoid drawing triplets from the CC
#    overwrite (boolean): overwriting the existing signature
#    sanitize (boolean): set to True to sanitize the dataset with trimming of less informative rows/columns. Setting 'sanitizer_kwargs' parameters different from the default ones 
#                        is possible. 
#    validations (boolean): set to False to skip post-signature data validations (including diagnostics which is run separately in a later step)
# Iterating on `V` axis 0: 100%|██████████| 1/1 [00:00<00:00, 249.74it/s]
# [INFO    ] Sanitized data shape: (310, 40)
# [INFO    ] STATUS: Aggregating
# [INFO    ] STATUS: Saving H5
# [INFO    ] Removing near duplicates.
# [INFO    ] Size before removing: 310
# [INFO    ] Size after removing: 244
# [INFO    ] Saving removed duplicates to: /aloy/home/mlocatelli/code/protocol_paper/local_cc_all/reference/M/M1/M1.001/sign0/sign0.h5
# [INFO    ] STATUS: Background distances
# [INFO    ] Background distances not available, computing them.
# [INFO    ] Background distances sample_pairs: 22339
# [INFO    ] Background distances not available, computing them.
# [INFO    ] Background distances sample_pairs: 22339
# [INFO    ] STATUS: FIT END

# %%
# Checking how many keys we have in sign0 full (redundant)...
sign0.info_h5
# Out:
# {'V': (310, 40),
#  'agg_method': (1,),
#  'date': (1,),
#  'features': (40,),
#  'input_type': (1,),
#  'keys': (310,),
#  'keys_raw': (310,),
#  'name': (1,)}

# %%
# ...and  sign0 reference (non-redundant)
sign0_ref = cc_local.get_signature(sign_type, 'reference', dataset)
sign0_ref.info_h5
# Out:
# {'V': (244, 40),
#  'features': (40,),
#  'keys': (244,),
#  'mappings': (310, 2),
#  'shape': (244, 40)}

# %%
# Running diagnostic plots on the just computed signature 0 (full)
sign_type_ref = 'sign0'
sign0 = cc_local.signature(dataset, sign_type)
diag0 = sign0.diagnosis()

# including the current dataset (M1.001) into the ROC diagnostic plot: by default just the official 25 CC spaces are used 
include_datasets = [dataset]
diag0.across_roc(include_datasets=include_datasets, save=True, plot=False)

size = 'medium'
# Diagnostic canvas parameters:
#     size (string): canvas size can be 'medium' (default) or 'small' (including a basic version of diagnostics)
#     savefig (boolean): set to True to save canvas in 'diags' folder
diag0.canvas(size=size, savefig=True)
# Out:
# [WARNING ] Not enough shared molecules

# %%
sign_type = 'sign0'
sign_type_ref = 'sign0'
size = 'medium'
canvas_path = os.path.join(local_cc, 'full', space[0], space, dataset, sign_type, 'diags', folder_name + '_' + sign_type_ref, dataset + '_' + sign_type + '_' + folder_name + '_' + sign_type_ref + '_' + size + '.png')  
display.Image(canvas_path)

# %% [markdown]
# # Signature 1: Cmpression of the signatures with a dimensionality typically retaining 90% of the original variance

# %%
# signature 0 model is used to fit signature 1: 
# Sign1 keep most of the complexity of the original data and can be used for similarity calculations.
sign_type = 'sign0'
sign0 = cc_local.get_signature(sign_type, 'full', dataset)

# %%
sign_type = 'sign1'
# Instantiation of signature 1 data structures: full and reference 
sign1 = cc_local.signature(dataset, sign_type)
# cleaning up sign1 full and sign1 reference file directories: if just one of the two signatures (full or reference) has to be clean use signX.clear()
sign1.clear_all()

# Creating the signature model: the typical preprocessing is a PCA (continuous data) or TF-IDF LSI.          
# Parameters: see for further details http://packages.sbnb-pages.irbbarcelona.org/chemical_checker/_autosummary/chemicalchecker.core.sign1.sign1.html
#    sign0 (signature data structure): a signature 0 
#    overwrite (boolean): overwriting the existing signature
#    validations (boolean): set to False to skip post-signature data validations (including diagnostics which is run separately in a later step)
#                           Current validation tests are performed on MOA (Mode Of Action) and ATC (Anatomical Therapeutic Chemical) corresponding to B1.001 and E1.001 space datasets.
#    model parameters different from the default ones can be passed to the fitting method (i.e. scale_kwargs={}, pca_kwargs={}, lsi_kwargs={})
sign1.fit(sign0, overwrite=True, validations=False)
# Out:
# [INFO    ] STATUS: FIT START
# [INFO    ] STATUS: Getting data
# [INFO    ] STATUS: LSI
# [INFO    ] Generating dictionary.
# [INFO    ] min_freq: 5
# [INFO    ] max_freq: 0.25
# [INFO    ] Fitting LSI model.
# [INFO    ] num_topics: 13
# [WARNING ] Dropped 67 molecules (only zeros).
# [WARNING ] Dropped 110 molecules (only zeros).
# [INFO    ] STATUS: Background distances
# [INFO    ] Background distances not available, computing them.
# [INFO    ] Background distances sample_pairs:
# [WARNING ] Identical signatures for 110 144
# [WARNING ] Identical signatures for 34 132
# [WARNING ] Identical signatures for 20 46
# [WARNING ] Identical signatures for 2 136
# [WARNING ] Identical signatures for 46 121
# [WARNING ] Identical signatures for 44 53
# [WARNING ] Identical signatures for 84 166
# [WARNING ] Identical signatures for 8 120
# [WARNING ] Identical signatures for 14 19
# [WARNING ] Identical signatures for 50 95
# [WARNING ] Identical signatures for 6 18
# [WARNING ] Identical signatures for 34 87
# [WARNING ] Identical signatures for 98 136
# [WARNING ] Identical signatures for 57 104
# [WARNING ] Identical signatures for 12 84
# [WARNING ] Identical signatures for 46 141
# [WARNING ] Identical signatures for 88 172
# [WARNING ] Identical signatures for 43 162
# [WARNING ] Identical signatures for 46 93
# [WARNING ] Identical signatures for 34 93
# [WARNING ] Identical signatures for 50 160
# [WARNING ] Identical signatures for 21 108
# [WARNING ] Identical signatures for 72 159
# [WARNING ] Identical signatures for 114 157
# [WARNING ] Identical signatures for 110 118
# [WARNING ] Identical signatures for 42 109
# [WARNING ] Identical signatures for 44 120
# [WARNING ] Identical signatures for 96 132
# [WARNING ] Identical signatures for 39 76
# [WARNING ] Identical signatures for 34 141
# [WARNING ] Identical signatures for 20 141
# [WARNING ] Identical signatures for 39 110
# [WARNING ] Identical signatures for 34 135
# [WARNING ] Identical signatures for 95 160
# [WARNING ] Identical signatures for 53 120
# [WARNING ] Identical signatures for 34 121
# [WARNING ] Identical signatures for 7 22
# [WARNING ] Identical signatures for 13 164
# [WARNING ] Identical signatures for 59 89
# [WARNING ] Identical signatures for 46 135
# [WARNING ] Identical signatures for 43 118
# [WARNING ] Identical signatures for 4 57
# [WARNING ] Identical signatures for 20 87
# [WARNING ] Identical signatures for 15 173
# [WARNING ] Identical signatures for 32 65
# [WARNING ] Identical signatures for 0 58
# [WARNING ] Identical signatures for 47 52
# [INFO    ] STATUS: FIT END

# %%
# TODO: double-check number of molecules and features
# Checking sign1 full data size
sign1.shape
# Out:
# (200, 13)

# %%
# Comparing to sign1 reference data size
sign1_ref = cc_local.get_signature(sign_type,'reference',dataset)
sign1_ref.shape
# Out:
# (177, 13)

# %%
# Producing sign1 (full) diagnostic plots
sign1 = cc_local.signature(dataset, 'sign1')
# diagnosis parameter: 
#    ref_cctype (string): the reference for the diagnostics is, by default, sign0 of the same dataset
diag1 = sign1.diagnosis()

# including the current dataset (M1.001) into the ROC diagnostic plot: by default just the official 25 CC spaces are used 
include_datasets = [dataset]
diag1.across_roc(include_datasets=include_datasets, save=True, plot=False)

size = 'medium'
# Diagnostic canvas parameters:
#     size (string): canvas size can be 'medium' (default) or 'small' (including a basic version of diagnostics)
#     savefig (boolean): set to True to save canvas in 'diags' folder
diag1.canvas(size=size, savefig=True)
# Out:
# [WARNING ] Not enough shared molecules
# [INFO    ] Loading faiss with AVX2 support.
# [INFO    ] Successfully loaded faiss with AVX2 support.
# [INFO    ] Removing near duplicates.
# [INFO    ] Size before removing: 200
# [INFO    ] Size after removing: 124
# [INFO    ] NumExpr defaulting to 4 threads.

# %%
sign_type = 'sign1'
sign_type_ref = 'sign0'
size = 'medium'
canvas_path = os.path.join(local_cc, 'full', space[0], space, dataset, sign_type, 'diags', folder_name + '_' + sign_type_ref, dataset + '_' + sign_type + '_' + folder_name + '_' + sign_type_ref + '_' + size + '.png')  
display.Image(canvas_path)

# %% [markdown]
# ## Signature1 Neighbours: Identifing nearest neighbors and distances

# %%
# Using sign1 full
sign1 = cc_local.get_signature(sign_type, 'full', dataset)
# TODO: double-check here: to get neighbors for reference molset ???
neig1_ref = cc_local.get_signature('neig1', 'reference', dataset)
# Cleaning up neig1 full and neig1 reference file directories
neig1_ref.clear_all()
# Fitting neighbor model given a sign1.
neig1_ref.fit(sign1)

# %% [markdown]
# ## Signature2: Network embedding of the similarity matrix derived from signatures 1

# %%
sign_type = 'sign2'
sign2 = cc_local.signature(dataset, sign_type)
# cleaning up sign2 full and sign2 reference file directories: if just one of the two signatures (full or reference) has to be clean use signX.clear()
sign2.clear_all()

# In this step of the pipeline is convenient, for computation, to work with the non-redundant set of signatures (reference). 
# At the end a mapping of the reference to the full set of molecules is performed.
sign2_ref = cc_local.get_signature(sign_type, 'reference', dataset)
#TODO: ask Martino about sign2 / sign2_ref

sign1 = cc_local.get_signature('sign1', 'full', dataset)
neig1_ref = cc_local.get_signature('neig1', 'reference', dataset)

# Signature 2 are network embeddings with fixed length and capture both explicit and implicit similarity relationships in the data.
# These signatures are the result of a two-step process:
#   Transforming nearest-neighbor of signature type 1 to graph.
#   Performing network embedding with Node2Vec.

# signature 2 given signature 1 and its nearest neighbors
# oos_predictor (boolean): set to False for skipping the predictor on out-of-space compounds
sign2_ref.fit(sign1, neig1_ref, oos_predictor=False, overwrite=True, validations=False)
# Out:
# [WARNING ] From /opt/miniconda3/envs/py37/lib/python3.7/site-packages/adanet/core/tpu_estimator.py:33: The name tf.estimator.tpu.TPUEstimator is deprecated. Please use tf.compat.v1.estimator.tpu.TPUEstimator instead.
#
# [INFO    ] STATUS: FIT START
# [INFO    ] STATUS: Node2Vec
# [INFO    ] Reading bg_distances file for metric: cosine
# [INFO    ] Nodes :          177
# [INFO    ] Edges :          801
# [INFO    ] -i:/aloy/home/mlocatelli/code/protocol_paper/local_cc_all/reference/M/M1/M1.001/sign2/models/node2vec/graph.edgelist -o:/aloy/home/mlocatelli/code/protocol_paper/local_cc_all/reference/M/M1/M1.001/sign2/models/node2vec/n2v.emb -d:128 -l:80 -r:10 -k:10 -e:1 -p:1 -q:1 -v -w
# [INFO    ] cpu: 1
# [INFO    ] Converting /aloy/home/mlocatelli/code/protocol_paper/local_cc_all/reference/M/M1/M1.001/sign2/models/node2vec/n2v.emb to /aloy/home/mlocatelli/code/protocol_paper/local_cc_all/reference/M/M1/M1.001/sign2/sign2.h5
# [INFO    ] words: 177 features: 128
# 100%|██████████| 177/177 [00:00<00:00, 3443.68it/s]
# [INFO    ] y_positive cases 531 : min 0.58 1st 0.95 2nd 0.98, 3rd 0.99 max 1.00
# [INFO    ] y_negative cases 531 : min 0.01 1st 0.42 2nd 0.49, 3rd 0.60 max 0.99
# [INFO    ] STATUS: Generating `full` molset
# [INFO    ] STATUS: Background distances
# [INFO    ] Background distances not available, computing them.
# [INFO    ] Background distances sample_pairs: 14735
# [INFO    ] Background distances not available, computing them.
# [INFO    ] Background distances sample_pairs: 14735
# [INFO    ] STATUS: FIT END

# %%
# Checking sign2 reference data size
sign2_ref.shape
# Out:
# (177, 128)

# %%
# and comparing it to sign2 full data size
sign2.shape
# Out:
# (200, 128)

# %%
# Producing sign2 (full) diagnostic plots
sign2 = cc_local.get_signature(sign_type, 'full', dataset)
# diagnosis parameter: 
#    ref_cctype (string): the reference for the diagnostics is, by default, sign0 of the same dataset
diag2 = sign2.diagnosis()

# including the current dataset (M1.001) into the ROC diagnostic plot: by default just the official 25 CC spaces are used 
include_datasets = [dataset]
diag2.across_roc(include_datasets=include_datasets, save=True, plot=False)

size = 'medium'
# Diagnostic canvas parameters:
#     size (string): canvas size can be 'medium' (default) or 'small' (including a basic version of diagnostics)
#     savefig (boolean): set to True to save canvas in 'diags' folder
diag2.canvas(size=size, savefig=True)
# Out:
# [WARNING ] Not enough shared molecules
# [INFO    ] Removing near duplicates.
# [INFO    ] Size before removing: 200
# [INFO    ] Size after removing: 172

# %%
sign_type = 'sign2'
sign_type_ref = 'sign0'
size = 'medium'
canvas_path = os.path.join(local_cc, 'full', space[0], space, dataset, sign_type, 'diags', folder_name + '_' + sign_type_ref, dataset + '_' + sign_type + '_' + folder_name + '_' + sign_type_ref + '_' + size + '.png')  
display.Image(canvas_path)

# %% [markdown]
# ## Signature 3: Fixed-length representation of the data capturing and inferring the original (sign1) similarity of the data

# %%
# initialization of sign3
sign_type = 'sign3'
sign3 = cc_local.signature(dataset, sign_type)
# cleaning up sign3 full and sign3 reference file directories: if just one of the two signatures (full or reference) has to be clean use signX.clear()
sign3.clear_all()

# %%
# Create a list of sign2 to feed sign3:
# using the 25 CC spaces + the new custom space
sign2_list = list()
# 25 CC space
for dataset in cc_local.coordinates:
    dataset += '.001' 
    sign2_list.append(cc_local.get_signature('sign2', 'full', dataset))
# adding new space to CC
sign2_list.append(cc_local.get_signature('sign2','full',dataset))
len(sign2_list)
# Out:
# 26

# %%
sign2 = cc_local.signature(dataset, 'sign2')
sign1 = cc_local.signature(dataset, 'sign1')

# %%
# Are there M1.001 molecules not present in the CC universe?
dataset = 'M1.001'
sign2 = cc_local.signature(dataset, 'sign2')
dataset_mols= sign2.keys
print("Molecules present in {} space: {}".format(dataset, sign2.shape[0]))
print("Intersection between {} and CC universe is: {}".format(dataset, len(set(dataset_mols).intersection(cc_local.universe))))
# Out:
# Molecules present in M1.001 space: 200
# Intersection between M1.001 and CC universe is: 188

# %%
# TODO: test on local run: h_vmem=2.2G...not that much RAM requested
# ask Martino different between sign2_universe and sign2_coverage

# Creating the signature model: Signatures type 3 are available for all molecules of the ChemicalChecker universe (~1M molecules)  
# Using HPC to run the model fit: more than 1CPU are requested reducing drastically the computation time because of parallelization

# Parameters: see for further details http://packages.sbnb-pages.irbbarcelona.org/chemical_checker/_autosummary/chemicalchecker.core.sign3.sign3.html
#    sign2_list (list of signatures): list of sign2 to learn from 
#    sign2_self (signature): sign2 of the current space (on which the sign3 fitting is run)
#    sign1_self (signature): sign1 of the current space (on which the sign3 fitting is run)
#    sign2_universe(string): path to the union of signatures 2 for all molecules in the CC universe (computed once only)
#    complete_universe (string): add chemistry information for molecules not in the universe. 
#                                ‘full’ uses all A* spaces while ‘fast’ skips A2 (3D conformation) which is very slow. 
#                                False by default, not adding any signature to the universe.
#    sign2_coverage (string): path to the coverage of signatures 2 for all molecules in the CC universe
#    overwrite (boolean): overwriting the existing signature
#    validations (boolean): set to False to skip post-signature data validations (including diagnostics which is run separately in a later step)
#                           Current validation tests are performed on MOA (Mode Of Action) and ATC (Anatomical Therapeutic Chemical) corresponding to B1.001 and E1.001 space datasets.
#    complete_universe: it completes the universe for extra molecules. Important if the dataset we are fitting is defined on molecules that largely do not overlap with CC molecules. 
#                       In that case there is no orthogonal information to derive sign3 so we should always have at least 
#                       the chemistry (calculated) level available for all molecules of the dataset.
#    cpu (int): HPC parameter, by default cpu=1
sign3.fit_hpc(sign2_list, sign2_self=sign2, sign1_self=sign1, sign2_universe=None, complete_universe='fast', sign2_coverage=None, overwrite=True, validations=False, cpu=8)
# Out:
# [INFO    ] Writing file /aloy/scratch/mlocatelli/CC/tmp_jobs/tmp_omfzv6xq/job-sign3_fit_hpc.py.sh...

# %%
# Producing sign3 (full) diagnostic plots
sign3 = cc_local.get_signature(sign_type, 'full', dataset)
# diagnosis parameter: 
#    ref_cctype (string): the reference for the diagnostics is, by default, sign0 of the same dataset
diag3 = sign3.diagnosis()

# including the current dataset (M1.001) into the ROC diagnostic plot: by default just the official 25 CC spaces are used 
include_datasets = [dataset]
diag3.across_roc(include_datasets=include_datasets, save=True, plot=False)

size = 'medium'
# Diagnostic canvas parameters:
#     size (string): canvas size can be 'medium' (default) or 'small' (including a basic version of diagnostics)
#     savefig (boolean): set to True to save canvas in 'diags' folder
diag3.canvas(size=size, savefig=True)
# Out:
# 2022-02-08 10:58:05,570 chemicalchecker.core.signature_base.BaseSignature [DEBUG   ] Loading signature: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/M/M1/M1.001/sign3
# 2022-02-08 10:58:05,573 chemicalchecker.core.chemcheck.ChemicalChecker [DEBUG   ] ChemicalChecker with root: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc

# %%
sign_type = 'sign3'
sign_type_ref = 'sign0'
size = 'medium'
canvas_path = os.path.join(local_cc, 'full', space[0], space, dataset, sign_type, 'diags', folder_name + '_' + sign_type_ref, dataset + '_' + sign_type + '_' + folder_name + '_' + sign_type_ref + '_' + size + '.png')  
display.Image(canvas_path)
# Out:
# 2022-02-08 11:04:06,903 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Computing or retrieving data for canvas medium.
# 2022-02-08 11:04:06,904 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Cosine distances
# 2022-02-08 11:04:06,908 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Euclidean distances
# 2022-02-08 11:04:06,917 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Projection
# 2022-02-08 11:04:06,933 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Image
# 2022-02-08 11:04:06,937 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Features bins
# 2022-02-08 11:04:06,944 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Keys bins
# 2022-02-08 11:04:07,043 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Values
# 2022-02-08 11:04:07,046 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Redundancy
# 2022-02-08 11:04:15,278 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Intensities
# 2022-02-08 11:04:15,294 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Intensities projection
# 2022-02-08 11:04:15,300 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Confidences
# 2022-02-08 11:04:15,320 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Confidences projection
# 2022-02-08 11:04:15,330 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Cluster sizes
# 2022-02-08 11:04:15,337 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Projection clusters
# 2022-02-08 11:04:15,348 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Dimensions
# 2022-02-08 11:04:15,352 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Key coverages
# 2022-02-08 11:04:16,200 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Across coverage
# 2022-02-08 11:04:16,215 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] ATC ROC
# 2022-02-08 11:04:16,224 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] MoA ROC
# 2022-02-08 11:04:16,232 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Across ROC
# 2022-02-08 11:04:16,258 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Sample-specific agreement to the rest of CC, based on a Z-global ranking
# 2022-02-08 11:04:16,559 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Global ranks agreement projection
# 2022-02-08 11:04:16,577 chemicalchecker.util.plot.diagnosticsplot.DiagnosisPlot [DEBUG   ] Plotting Canvas medium
# 2022-02-08 11:04:27,614 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Saving plot to: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/M/M1/M1.001/sign3/diags/local_cc_sign0/M1.001_sign3_local_cc_sign0_medium.png

# %%
# small canvases for comparative analysis of sign0 - sign1 - sign2 -sign3
diag0.canvas(size='small', savefig=True)
diag1.canvas(size='small', savefig=True)
diag2.canvas(size='small', savefig=True)
diag3.canvas(size='small', savefig=True)
# Out:
# 2022-01-27 16:18:55,786 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Computing or retrieving data for canvas small.
# 2022-01-27 16:18:55,787 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Cosine distances
# 2022-01-27 16:18:55,829 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Euclidean distances
# 2022-01-27 16:18:55,868 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Projection
# 2022-01-27 16:18:55,904 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Image
# 2022-01-27 16:18:55,944 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Features bins
# 2022-01-27 16:18:55,971 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Keys bins
# 2022-01-27 16:18:55,998 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Values
# 2022-01-27 16:18:56,032 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Redundancy
# 2022-01-27 16:18:56,065 chemicalchecker.util.plot.diagnosticsplot.DiagnosisPlot [DEBUG   ] Plotting Canvas small
# [INFO    ] NumExpr defaulting to 4 threads.
# 2022-01-27 16:18:56,366 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Saving plot to: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/M/M1/M1.001/sign0/diags/local_cc_sign0/M1.001_sign0_local_cc_sign0_small.png
# 2022-01-27 16:18:56,656 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Computing or retrieving data for canvas small.
# 2022-01-27 16:18:56,657 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Cosine distances
# 2022-01-27 16:18:56,682 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Euclidean distances
# 2022-01-27 16:18:56,736 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Projection
# 2022-01-27 16:18:56,752 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Image
# 2022-01-27 16:18:56,772 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Features bins
# 2022-01-27 16:18:56,797 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Keys bins
# 2022-01-27 16:18:56,845 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Values
# 2022-01-27 16:18:56,869 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Redundancy
# 2022-01-27 16:18:56,890 chemicalchecker.util.plot.diagnosticsplot.DiagnosisPlot [DEBUG   ] Plotting Canvas small
# 2022-01-27 16:18:57,151 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Saving plot to: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/M/M1/M1.001/sign1/diags/local_cc_sign0/M1.001_sign1_local_cc_sign0_small.png
# 2022-01-27 16:18:57,512 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Computing or retrieving data for canvas small.
# 2022-01-27 16:18:57,512 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Cosine distances
# 2022-01-27 16:18:57,537 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Euclidean distances
# 2022-01-27 16:18:57,575 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Projection
# 2022-01-27 16:18:57,593 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Image
# 2022-01-27 16:18:57,617 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Features bins
# 2022-01-27 16:18:57,630 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Keys bins
# 2022-01-27 16:18:57,676 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Values
# 2022-01-27 16:18:57,694 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Redundancy
# 2022-01-27 16:18:57,720 chemicalchecker.util.plot.diagnosticsplot.DiagnosisPlot [DEBUG   ] Plotting Canvas small
# 2022-01-27 16:18:57,979 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Saving plot to: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/M/M1/M1.001/sign2/diags/local_cc_sign0/M1.001_sign2_local_cc_sign0_small.png
# 2022-01-27 16:18:58,430 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Computing or retrieving data for canvas small.
# 2022-01-27 16:18:58,430 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Cosine distances
# 2022-01-27 16:18:58,456 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Euclidean distances
# 2022-01-27 16:18:58,471 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Projection
# 2022-01-27 16:18:58,546 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Image
# 2022-01-27 16:18:58,554 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Features bins
# 2022-01-27 16:18:58,575 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Keys bins
# 2022-01-27 16:18:58,887 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Values
# 2022-01-27 16:18:58,898 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Redundancy
# 2022-01-27 16:19:06,579 chemicalchecker.util.plot.diagnosticsplot.DiagnosisPlot [DEBUG   ] Plotting Canvas small
# 2022-01-27 16:19:15,782 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Saving plot to: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/M/M1/M1.001/sign3/diags/local_cc_sign0/M1.001_sign3_local_cc_sign0_small.png

# %%
sign_type = 'sign0'
sign_type_ref = 'sign0'
size = 'small'
canvas_path = os.path.join(local_cc, 'full', space[0], space, dataset, sign_type, 'diags', folder_name + '_' + sign_type_ref, dataset + '_' + sign_type + '_' + folder_name + '_' + sign_type_ref + '_' + size + '.png')  
display.Image(canvas_path)

# %%
sign_type = 'sign1'
sign_type_ref = 'sign0'
size = 'small'
canvas_path = os.path.join(local_cc, 'full', space[0], space, dataset, sign_type, 'diags', folder_name + '_' + sign_type_ref, dataset + '_' + sign_type + '_' + folder_name + '_' + sign_type_ref + '_' + size + '.png')  
display.Image(canvas_path)

# %%
sign_type = 'sign2'
sign_type_ref = 'sign0'
size = 'small'
canvas_path = os.path.join(local_cc, 'full', space[0], space, dataset, sign_type, 'diags', folder_name + '_' + sign_type_ref, dataset + '_' + sign_type + '_' + folder_name + '_' + sign_type_ref + '_' + size + '.png')  
display.Image(canvas_path)

# %%
sign_type = 'sign3'
sign_type_ref = 'sign0'
size = 'small'
canvas_path = os.path.join(local_cc, 'full', space[0], space, dataset, sign_type, 'diags', folder_name + '_' + sign_type_ref, dataset + '_' + sign_type + '_' + folder_name + '_' + sign_type_ref + '_' + size + '.png')  
display.Image(canvas_path)

# %%
sign3 = cc_local.signature(dataset, 'sign3')
diag3 = sign3.diagnosis()
diag3.across_roc(include_datasets=['M1.001'],save=True, plot=True, redo = True)
# Out:
# 2022-02-07 23:40:17,915 chemicalchecker.core.signature_base.BaseSignature [DEBUG   ] Loading signature: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/M/M1/M1.001/sign3

# %%
print(sign3.info_h5)
print(sign0.info_h5)
# Out:
# {'V': (1009305, 128), 'applicability': (1009305,), 'confidence': (1009305,), 'datasets': (26,), 'keys': (1009305,), 'known': (1009305,), 'prior': (1009305,), 'prior_signature': (1009305,), 'robustness': (1009305,), 'shape': (2,)}
# {'V': (310, 40), 'agg_method': (1,), 'date': (1,), 'features': (40,), 'input_type': (1,), 'keys': (310,), 'keys_raw': (310,), 'name': (1,)}

# %%
with h5py.File('./local_cc/full/M/M1/M1.001/sign3/sign3.h5', 'r') as hf:
    sign3_keys = hf['keys'].asstr()[:]
with h5py.File('./local_cc/full/M/M1/M1.001/sign0/sign0.h5', 'r') as hf:
    sign0_keys = hf['keys'].asstr()[:]

# %%
mask = []
for key in sign3_keys:
    mask.append(key in sign0_keys)
known_keys = sign3_keys[mask]
print(known_keys.shape)

keys_subsample, V_subsample = sign3.get_vectors(known_keys)
# Out:
# 2022-02-07 23:42:02,136 chemicalchecker.core.signature_data.DataSignature [DEBUG   ] Fetching 305 rows from dataset V

# %%
sign3_subsample_path = './local_cc/full/M/M1/M1.001/sign3/sign3_subsample.h5'
with h5py.File(sign3_subsample_path, 'w') as hf:
    hf.create_dataset('V', data=V_subsample)
    hf.create_dataset('keys', data=known_keys)

# %%
sign3_subsample = h5py.File(sign3_subsample_path, 'r')
infos = dict()
for key in sign3_subsample.keys():
    infos[key] = sign3_subsample[key].shape
print(infos)
# Out:
# {'V': (305, 128), 'keys': (305,)}

# %%
sign3_subsample = cc_local.signature(dataset, 'sign3')
diag3_subsample = sign3_subsample.diagnosis()
# Out:
# 2022-02-08 00:09:34,927 chemicalchecker.core.signature_base.BaseSignature [DEBUG   ] Loading signature: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/M/M1/M1.001/sign3
# 2022-02-08 00:09:34,930 chemicalchecker.core.chemcheck.ChemicalChecker [DEBUG   ] ChemicalChecker with root: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc

# %%
diag3_subsample.across_roc(include_datasets=['M1.001'],save=False, plot=True, redo=True)
# Out:
# 2022-02-07 23:47:19,302 chemicalchecker.core.diagnostics.Diagnosis [DEBUG   ] Across ROC
# 2022-02-07 23:47:19,304 chemicalchecker.core.signature_base.BaseSignature [DEBUG   ] Loading signature: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/A/A1/A1.001/sign0
# 2022-02-07 23:47:21,728 chemicalchecker.core.signature_base.BaseSignature [DEBUG   ] Loading signature: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/A/A1/A1.001/sign0
# 2022-02-07 23:47:30,078 chemicalchecker.core.signature_data.DataSignature [DEBUG   ] Fetching 293 rows from dataset V
# 2022-02-07 23:47:37,083 chemicalchecker.core.signature_data.DataSignature [DEBUG   ] Fetching 293 rows from dataset V
# 2022-02-07 23:47:37,430 chemicalchecker.core.signature_base.BaseSignature [DEBUG   ] Loading signature: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/A/A2/A2.001/sign0
# 2022-02-07 23:47:37,721 chemicalchecker.core.signature_base.BaseSignature [DEBUG   ] Loading signature: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/A/A2/A2.001/sign0
# 2022-02-07 23:47:42,777 chemicalchecker.core.signature_data.DataSignature [DEBUG   ] Fetching 254 rows from dataset V
# 2022-02-07 23:47:47,444 chemicalchecker.core.signature_data.DataSignature [DEBUG   ] Fetching 254 rows from dataset V
# 2022-02-07 23:47:47,565 chemicalchecker.core.signature_base.BaseSignature [DEBUG   ] Loading signature: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/A/A3/A3.001/sign0
# 2022-02-07 23:47:47,765 chemicalchecker.core.signature_base.BaseSignature [DEBUG   ] Loading signature: /aloy/home/mlocatelli/code/protocol_paper/MICROBIOTA/notebooks/local_cc/full/A/